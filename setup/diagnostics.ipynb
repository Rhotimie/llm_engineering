# %% [markdown]
# # Gathering Essential Diagnostic information
#
# ## Please run this next cell to gather some important data
#
# Please run the next cell; it should take a minute or so to run (mostly the network test).
# Then email me the output of the last cell to ed@edwarddonner.com.
# Alternatively: this will create a file called report.txt - just attach the file to your email.

# %%
# Run my diagnostics report to collect key information for debugging
# Please email me the results. Either copy & paste the output, or attach the file report.txt

# !pip install -q requests speedtest-cli psutil setuptools
from diagnostics import Diagnostics
Diagnostics().run()
# Out:
# WARNING: Error parsing dependencies of bleach: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     tinycss2 (>=1.1.0<1.2) ; extra == 'css'
#              ~~~~~~~~^
# Starting diagnostics at 2026-07-27 12:50:40
#
# ===== System Information =====
# Operating System: Darwin
# MacOS Version: 15.7.7
# Architecture: ('64bit', '')
# Machine: x86_64
# Processor: i386
# Total RAM: 16.00 GB
# Available RAM: 6.80 GB
# Free Disk Space: 232.99 GB
#
# ===== File System Information =====
# Current Directory: /Users/user/Desktop/ai_engineer/llm_engineering/setup
# Write permission: OK
#
# Files in Current Directory:
#  - SETUP-new.md
#  - __pycache__
#  - diagnostics.ipynb
#  - diagnostics.py
#  - report.txt
#  - troubleshooting.ipynb
#
# ===== Git Repository Information =====
# Git Repository Root: /Users/user/Desktop/ai_engineer/llm_engineering
# Current Commit: 62ffdc419fdf58574302e8653444eed3fe13a6ef
# Remote Origin: https://github.com/ed-donner/llm_engineering.git
#
# ===== Environment File Check =====
# .env file exists at: /Users/user/Desktop/ai_engineer/llm_engineering/.env
# OPENAI_API_KEY found in .env file
# WARNING: Additional .env file found at: /Users/user/Desktop/ai_engineer/llm_engineering/.vscode/.env
#
# ===== Anaconda Environment Check =====
# Anaconda environment is active:
# Environment Path: /Users/user/opt/anaconda3
# Environment Name: anaconda3
# Conda Version: conda 22.9.0
#
# Python Environment:
# Python Version: 3.12.12 (main, Feb 12 2026, 01:24:40) [Clang 21.1.4 ]
# Python Executable: /Users/user/Desktop/ai_engineer/llm_engineering/.venv/bin/python
# ERROR: Could not import 'pkg_resources' to check installed packages
#
# ===== Virtualenv Check =====
# Virtualenv is active:
# Environment Path: /Users/user/Desktop/ai_engineer/llm_engineering/.venv
# Environment Name: .venv
#
# Python Environment:
# Python Version: 3.12.12 (main, Feb 12 2026, 01:24:40) [Clang 21.1.4 ]
# Python Executable: /Users/user/Desktop/ai_engineer/llm_engineering/.venv/bin/python
# ERROR: Could not import 'pkg_resources' to check installed packages
#
# ===== Network Connectivity Check =====
# SSL Version: OpenSSL 3.5.5 27 Jan 2026
# ✓ Connected to https://www.google.com
#   Response time: 0.68s
#
# Performing bandwidth test using speedtest-cli...
# Download speed: 35.04 Mbps
# Upload speed: 14.18 Mbps
#
# ===== Environment Variables Check =====
#
# PYTHONPATH is not set.
#
# Python sys.path:
#  - /Users/user/.local/share/uv/python/cpython-3.12.12-macos-x86_64-none/lib/python312.zip
#  - /Users/user/.local/share/uv/python/cpython-3.12.12-macos-x86_64-none/lib/python3.12
#  - /Users/user/.local/share/uv/python/cpython-3.12.12-macos-x86_64-none/lib/python3.12/lib-dynload
#  -
#  - /Users/user/Desktop/ai_engineer/llm_engineering/.venv/lib/python3.12/site-packages
# WARNING: OPENAI_API_KEY environment variable is not set after calling load_dotenv()
#
# ===== Additional Diagnostics =====
# Temp directory is writable: /var/folders/vs/yf7dl8_s4sd4yy5hm2jbljq40000gn/T
#
# ===== Warnings Found =====
# The following warnings were detected. They might not prevent the program from running but could cause unexpected behavior:
# - Additional .env file found at: /Users/user/Desktop/ai_engineer/llm_engineering/.vscode/.env
# - OPENAI_API_KEY environment variable is not set after calling load_dotenv()
#
# ===== Errors Found =====
# The following critical issues were detected. Please address them before proceeding:
# - Could not import 'pkg_resources' to check installed packages
# - Could not import 'pkg_resources' to check installed packages
#
#
# Completed diagnostics at 2026-07-27 12:51:20
#
#
# Please send these diagnostics to me at ed@edwarddonner.com
# Either copy & paste the above output into an email, or attach the file report.txt that has been created in this directory.
